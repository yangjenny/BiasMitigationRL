# %%
# %%time

# %run BiasMitigationRL/run.py
# Out:
# Reward for each class (z).
# 	- Class 0 : 0.8175
# 	- Class 1 : 0.5759
#
# Reward for each class label.
# 	- Class 0 : 0.4928
# 	- Class 1 : 0.8701
# Start training
# Training Scores
# train_step : 1000, epsilon : 0.010
# num samples: 1000
# Test results
# Accuracy: 0.553
# Recall: 0.235
# Precision: 0.207
# Specificity: 0.669
# F1 Score: 0.220
# PPV: 0.207
# NPV: 0.705
# AUC: 0.400
#
#
# Validation Scores
# train_step : 1000, epsilon : 0.010
# num samples: 9769
# Test results
# Accuracy: 0.546
# Recall: 0.273
# Precision: 0.186
# Specificity: 0.631
# F1 Score: 0.221
# PPV: 0.186
# NPV: 0.737
# AUC: 0.427
#
#
# Training Scores
# train_step : 2000, epsilon : 0.010
# num samples: 2000
# Test results
# Accuracy: 0.608
# Recall: 0.181
# Precision: 0.196
# Specificity: 0.750
# F1 Score: 0.188
# PPV: 0.196
# NPV: 0.732
# AUC: 0.424
#
#
# Validation Scores
# train_step : 2000, epsilon : 0.010
# num samples: 9769
# Test results
# Accuracy: 0.644
# Recall: 0.218
# Precision: 0.231
# ...
